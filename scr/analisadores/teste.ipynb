# %%
# Exemplo de uso
from analisadores.fabrica import analisar_grafico

# Com tipo especificado
resultado = analisar_grafico(
    imagem_path=r'scr\data\pizza\pizza_3d.png',
    tipo='pizza',
    num_categorias=4
)

# Com detecção automática
resultado = analisar_grafico(
    imagem_path='data/exemplos/grafico.png',
    num_categorias=5
)

if not resultado.get('erro'):
    print(f"Título: {resultado['metadados']['titulo']}")
    print(f"Confiança: {resultado['confianca']}%")
